# %%
from sklearn.datasets import load_iris
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.cross_validation import train_test_split

# %%
iris = load_iris()
#print iris.data
#print iris.target
#print iris.target_names
X = iris.data
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4)

# %%
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred = knn.predict(X_test)
print accuracy_score(y_test,y_pred)
# Out:
# 0.933333333333

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression(C=100)
logreg.fit(X,y)
y_test = logreg.predict(X)
print accuracy_score(y,y_test)
# Out:
# 0.98

# %%
y_y = dict()
for i in np.arange(0.001,100,0.3):
#for i in np.arange(1,5,1):
    logreg = LogisticRegression(C=i)
    logreg.fit(X,y)
    y_y[i] = accuracy_score(logreg.predict(X),y)

import collections
y_y = collections.OrderedDict(sorted(y_y.items()))

# %%
print y_y.keys()
print y_y.values()
# Out:
# [0.001, 0.30099999999999999, 0.60099999999999998, 0.90099999999999991, 1.2009999999999998, 1.5009999999999999, 1.8009999999999997, 2.101, 2.4009999999999998, 2.7009999999999996, 3.0009999999999999, 3.3009999999999997, 3.6009999999999995, 3.9009999999999998, 4.2010000000000005, 4.5010000000000003, 4.8010000000000002, 5.101, 5.4009999999999998, 5.7010000000000005, 6.0010000000000003, 6.3010000000000002, 6.601, 6.9009999999999998, 7.2009999999999996, 7.5010000000000003, 7.8010000000000002, 8.1009999999999991, 8.4009999999999998, 8.7009999999999987, 9.0009999999999994, 9.3009999999999984, 9.6009999999999991, 9.9009999999999998, 10.200999999999999, 10.500999999999999, 10.800999999999998, 11.100999999999999, 11.401, 11.700999999999999, 12.000999999999999, 12.300999999999998, 12.600999999999999, 12.901, 13.200999999999999, 13.500999999999999, 13.800999999999998, 14.100999999999999, 14.400999999999998, 14.700999999999999, 15.000999999999999, 15.300999999999998, 15.600999999999999, 15.9009999
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(y_y.keys(),y_y.values())
plt.show()
