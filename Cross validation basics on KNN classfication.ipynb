# %%
from sklearn.datasets import load_iris
#from sklearn.cross_validation import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
# %matplotlib inline

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
score = dict();
for i in np.arange(1,25):
    KNN = KNeighborsClassifier(n_neighbors=i)
    score[i] = cross_val_score(KNN,X,y,scoring='accuracy',cv=10).mean()

# %%
plt.plot(score.keys(), score.values())
print 'Max accuracy - '
print zip(['Best n_neighbors value = ','% accuracy =' ],max(score.iteritems(), key=(lambda x: x[1])))
# Out:
# Max accuracy -
# [('Best n_neighbors value = ', 13), ('% accuracy =', 0.98000000000000009)]
